# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()


client = genai.Client(api_key=os.environ['Gemini_API_KEY'])

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="天空為什麼是藍的"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[4], line 9
#       4 load_dotenv()
#       7 client = genai.Client(api_key=os.environ['Gemini_API_KEY'])
# ----> 9 response = client.models.generate_content(
#      10     model="gemini-2.5-flash", contents="天空為什麼是藍的"
#      11 )
#      12 print(response.text)
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/google/genai/models.py:5898, in Models.generate_content(self, model, contents, config)
#    5896 while remaining_remote_calls_afc > 0:
#    5897   i += 1
# -> 5898   response = self._generate_content(
#    5899       model=model, contents=contents, config=parsed_config
#    5900   )
#    5901   logger.info(f'AFC remote call {i} is done.')
#    5902   remaining_remote_calls_afc -= 1
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/google/genai/models.py:4838, in Models._generate_content(self, model, contents, config)
#    4835 request_dict = _common.convert_to_dict(request_dict)
#    4836 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4838 response = self._api_client.request(
#    4839     'post', path, request_dict, http_options
#    4840 )
#    4842 response_dict = '' if not response.body else json.loads(response.body)
#    4844 if self._api_client.vertexai:
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/google/genai/_api_client.py:1077, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1067 def request(
#    1068     self,
#    1069     http_method: str,
#    (...)
#    1072     http_options: Optional[HttpOptionsOrDict] = None,
#    1073 ) -> SdkHttpResponse:
#    1074   http_request = self._build_request(
#    1075       http_method, path, request_dict, http_options
#    1076   )
# -> 1077   response = self._request(http_request, stream=False)
#    1078   response_body = (
#    1079       response.response_stream[0] if response.response_stream else ''
#    1080   )
#    1081   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/google/genai/_api_client.py:968, in BaseApiClient._request(self, http_request, stream)
#     963 def _request(
#     964     self,
#     965     http_request: HttpRequest,
#     966     stream: bool = False,
#     967 ) -> HttpResponse:
# --> 968   return self._retry(self._request_once, http_request, stream)
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/google/genai/_api_client.py:951, in BaseApiClient._request_once(self, http_request, stream)
#     947   return HttpResponse(
#     948       response.headers, response if stream else [response.text]
#     949   )
#     950 else:
# --> 951   response = self._httpx_client.request(
#     952       method=http_request.method,
#     953       url=http_request.url,
#     954       headers=http_request.headers,
#     955       content=data,
#     956       timeout=http_request.timeout,
#     957   )
#     958   errors.APIError.raise_for_response(response)
#     959   return HttpResponse(
#     960       response.headers, response if stream else [response.text]
#     961   )
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/httpx/_client.py:812, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     805     message = (
#     806         "Setting per-request cookies=<...> is being deprecated, because "
#     807         "the expected behaviour on cookie persistence is ambiguous. Set "
#     808         "cookies directly on the client instance instead."
#     809     )
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
# --> 812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#     815     content=content,
#     816     data=data,
#     817     files=files,
#     818     json=json,
#     819     params=params,
#     820     headers=headers,
#     821     cookies=cookies,
#     822     timeout=timeout,
#     823     extensions=extensions,
#     824 )
#     825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/httpx/_client.py:367, in BaseClient.build_request(self, method, url, content, data, files, json, params, headers, cookies, timeout, extensions)
#     355 """
#     356 Build and return a request instance.
#     357
#    (...)
#     364 [0]: /advanced/clients/#request-instances
#     365 """
#     366 url = self._merge_url(url)
# --> 367 headers = self._merge_headers(headers)
#     368 cookies = self._merge_cookies(cookies)
#     369 params = self._merge_queryparams(params)
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/httpx/_client.py:430, in BaseClient._merge_headers(self, headers)
#     425 """
#     426 Merge a headers argument together with any headers on the client,
#     427 to create the headers used for the outgoing request.
#     428 """
#     429 merged_headers = Headers(self.headers)
# --> 430 merged_headers.update(headers)
#     431 return merged_headers
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/httpx/_models.py:275, in Headers.update(self, headers)
#     274 def update(self, headers: HeaderTypes | None = None) -> None:  # type: ignore
# --> 275     headers = Headers(headers)
#     276     for key in headers.keys():
#     277         if key in self:
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/httpx/_models.py:156, in Headers.__init__(self, headers, encoding)
#     154     for k, v in headers.items():
#     155         bytes_key = _normalize_header_key(k, encoding)
# --> 156         bytes_value = _normalize_header_value(v, encoding)
#     157         self._list.append((bytes_key, bytes_key.lower(), bytes_value))
#     158 elif headers is not None:
#
# File /Applications/Utilities/miniconda3/envs/myenv/lib/python3.10/site-packages/httpx/_models.py:82, in _normalize_header_value(value, encoding)
#      80 if not isinstance(value, str):
#      81     raise TypeError(f"Header value must be str or bytes, not {type(value)}")
# ---> 82 return value.encode(encoding or "ascii")
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 0-1: ordinal not in range(128)
