# %% [markdown]
# https://www.perplexity.ai/search/0eafd6c8-1230-4d5d-9553-446ea1f18997

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = {'年廣告費投入':[12.5, 15.3, 23.2, 26.4, 33.5, 34.4, 39.4, 45.2, 55.4, 60.9],
            '月均銷售額':[21.2, 23.9, 32.9, 34.1, 42.5, 43.2, 49.0, 52.8, 59.4, 63.5]}
dataFrame = pd.DataFrame(data, index=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])
figure = plt.figure(figsize=(8, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(dataFrame.index,dataFrame.values,linestyle='--',marker='o')
plt.show()

# %%
corr_value = dataFrame['年廣告費投入'].corr(dataFrame['月均銷售額'])
print(f"線性相關性為{corr_value:.2f}")
# Out:
# 線性相關性為0.99

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = {'年廣告費投入':[12.5, 15.3, 23.2, 26.4, 33.5, 34.4, 39.4, 45.2, 55.4, 60.9],
            '月均銷售額':[21.2, 23.9, 32.9, 34.1, 42.5, 43.2, 49.0, 52.8, 59.4, 63.5]}
dataFrame = pd.DataFrame(data, index=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])
#figure = plt.figure(figsize=(8, 5))
#axes = figure.add_subplot(1,1,1)

#簡單的寫法
#如果有figure,建立一個figure
#如果沒有Axes,建立一個Axes
#如果有figure,就使用這個figure
#如果有Axes,就使用這個Axes
plt.figure(figsize=(8, 5))
plt.plot(dataFrame.index,dataFrame['年廣告費投入'].values,linestyle='--',marker='o')
plt.plot(dataFrame.index,dataFrame['月均銷售額'].values,linestyle='--',marker='o')
plt.show()
